# %%
import pandas as pd
dataset = pd.read_csv('Housing.csv')

# %%
dataset
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
print(dataset.shape)
# Out:
# (506, 15)

# %%
dataset[:5]
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
dataset = pd.concat([dataset['medv'],dataset.drop(['medv'], axis=1)],axis=1)
dataset
# Out:
#      medv  Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  \
# 0    24.0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900
# 1    21.6           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671
# 2    34.7           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671
# 3    33.4           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622
# 4    36.2           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622
# ..    ...         ...      ...   ...    ...   ...    ...    ...   ...     ...
# 501  22.4         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786
# 502  20.6         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875
# 503  23.9         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675
# 504  22.0         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889
# 505  11.9         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050
#
#      rad  tax  ptratio   black  lstat
# 0      1  296     15.3  396.90   4.98
# 1      2  242     17.8  396.90   9.14
# 2      2  242     17.8  392.83   4.03
# 3      3  222     18.7  394.63   2.94
# 4      3  222     18.7  396.90   5.33
# ..   ...  ...      ...     ...    ...
# 501    1  273     21.0  391.99   9.67
# 502    1  273     21.0  396.90   9.08
# 503    1  273     21.0  396.90   5.64
# 504    1  273     21.0  393.45   6.48
# 505    1  273     21.0  396.90   7.88
#
# [506 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
training_dataset, validation_dataset = train_test_split(dataset, test_size=0.1)

# %%
training_dataset.to_csv('training_dataset.csv', index=False, header=False)
validation_dataset.to_csv('validation_dataset.csv',index=False, header=False)

# %%
import sagemaker
sess = sagemaker.Session()
bucket = sess.default_bucket()

# %%
prefix = 'boston-housing'
training_data_path = sess.upload_data(
 path='training_dataset.csv',
 key_prefix=prefix + '/input/training')
validation_data_path = sess.upload_data(
 path='validation_dataset.csv',
 key_prefix=prefix + '/input/validation')
print(training_data_path)
print(validation_data_path)
# Out:
# s3://sagemaker-us-west-2-373913539787/boston-housing/input/training/training_dataset.csv
# s3://sagemaker-us-west-2-373913539787/boston-housing/input/validation/validation_dataset.csv

# %%
import boto3
from sagemaker import image_uris
region = boto3.Session().region_name
container = image_uris.retrieve('linear-learner', region)

# %%
from sagemaker.estimator import Estimator
ll_estimator = Estimator(container,role=sagemaker.get_execution_role(),
 instance_count=1,
 instance_type='ml.m4.xlarge',
 output_path='s3://{}/{}/output'.format(bucket,
 prefix))

# %%
ll_estimator.set_hyperparameters(
 predictor_type='regressor',
 mini_batch_size=32)

# %%
training_data_channel = sagemaker.TrainingInput(
 s3_data=training_data_path,
 content_type='text/csv')

# %%
validation_data_channel = sagemaker.TrainingInput(
 s3_data=validation_data_path,
 content_type='text/csv')

# %%
ll_estimator.fit({'train': training_data_channel,
 'validation': validation_data_channel})
# Out:
# 2021-04-05 17:50:47 Starting - Starting the training job...
# 2021-04-05 17:51:10 Starting - Launching requested ML instancesProfilerReport-1617645047: InProgress
# ......
# 2021-04-05 17:52:11 Starting - Preparing the instances for training......
# 2021-04-05 17:53:11 Downloading - Downloading input data...
# 2021-04-05 17:53:40 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
#
# 2021-04-05 17:54:16 Uploading - Uploading generated training model[04/05/2021 17:54:07 INFO 139804451579712] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [04/05/2021 17:54:07 INFO 139804451579712] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'predictor_type': 'regressor', 'mini_batch_size': '32'}
# [04/05/2021 17:54:07 INFO 139804451579712] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [04/05/2021 17:54:07 WARNING 139804451579712] Loggers have already been setup.
# Process 1 is a worker.
# [04/05/2021 17:54:07 INFO 139804451579712] Using default worker.
# [04/05/2021 17:54:07 INFO 139804451579712] Checkpoint loading and saving are disabled.
# [04/05/2021 17:54:07 INFO 139804451579712] Create Store: local
# [04/05/2021 17:54:07 INFO 139804451579712] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f266207d110>
# [04/05/2021 17:54:07 INFO 139804451579712] Scaling model computed with parameters:
#  {'stdev_label':
# [9.233138]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [1.4612917e+02 8.2303534e+00 2.2778988e+01 6.7809625e+00 2.4605261e-01
#  1.1602397e-01 6.8146646e-01 2.8037327e+01 2.0618494e+00 8.6895752e+00
#  1.6801363e+02 2.1699038e+00 8.9359222e+01 7.1448441e+00]
# <NDArray 14 @cpu(0)>, 'mean_label':
# [22.474558]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [2.5401340e+02 3.5271220e+00 1.0934153e+01 1.1102545e+01 6.4732149e-02
#  5.5585647e-01 6.2835631e+00 6.8889061e+01 3.7533684e+00 9.4843750e+00
#  4.0692184e+02 1.8464958e+01 3.5775644e+02 1.2711719e+01]
# <NDArray 14 @cpu(0)>}
# [04/05/2021 17:54:07 INFO 139804451579712] nvidia-smi: took 0.032 seconds to run.
# [04/05/2021 17:54:07 INFO 139804451579712] nvidia-smi identified 0 GPUs.
# [04/05/2021 17:54:07 INFO 139804451579712] Number of GPUs being used: 0
# #metrics {"StartTime": 1617645247.9795508, "EndTime": 1617645247.9795883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 487.0, "count": 1, "min": 487, "max": 487}, "Total Batches Seen": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 1617645248.441521, "EndTime": 1617645248.4415865, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7784910500049591, "count": 1, "min": 0.7784910500049591, "max": 0.7784910500049591}}}
#
# #metrics {"StartTime": 1617645248.4416802, "EndTime": 1617645248.4417045, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.781989295567785, "count": 1, "min": 0.781989295567785, "max": 0.781989295567785}}}
#
# #metrics {"StartTime": 1617645248.441765, "EndTime": 1617645248.4417827, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.7091996520757675, "count": 1, "min": 0.7091996520757675, "max": 0.7091996520757675}}}
#
# #metrics {"StartTime": 1617645248.441842, "EndTime": 1617645248.441861, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.7049642758710044, "count": 1, "min": 0.7049642758710044, "max": 0.7049642758710044}}}
#
# #metrics {"StartTime": 1617645248.4419227, "EndTime": 1617645248.4419389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.7888422012329102, "count": 1, "min": 0.7888422012329102, "max": 0.7888422012329102}}}
#
# #metrics {"StartTime": 1617645248.4419913, "EndTime": 1617645248.442007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.7935321501323155, "count": 1, "min": 0.7935321501323155, "max": 0.7935321501323155}}}
#
# #metrics {"StartTime": 1617645248.4420698, "EndTime": 1617645248.4420886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.7936851041657584, "count": 1, "min": 0.7936851041657584, "max": 0.7936851041657584}}}
#
# #metrics {"StartTime": 1617645248.4421477, "EndTime": 1617645248.4421668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.7959930215563092, "count": 1, "min": 0.7959930215563092, "max": 0.7959930215563092}}}
#
# #metrics {"StartTime": 1617645248.442234, "EndTime": 1617645248.442253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.9623161809785026, "count": 1, "min": 0.9623161809785026, "max": 0.9623161809785026}}}
#
# #metrics {"StartTime": 1617645248.4423118, "EndTime": 1617645248.4423294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.7031713894435337, "count": 1, "min": 0.7031713894435337, "max": 0.7031713894435337}}}
#
# #metrics {"StartTime": 1617645248.4423769, "EndTime": 1617645248.442395, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6814575472048351, "count": 1, "min": 0.6814575472048351, "max": 0.6814575472048351}}}
#
# #metrics {"StartTime": 1617645248.4424548, "EndTime": 1617645248.4424741, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.7757417453186852, "count": 1, "min": 0.7757417453186852, "max": 0.7757417453186852}}}
#
# #metrics {"StartTime": 1617645248.4425197, "EndTime": 1617645248.4425364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.7727567276784352, "count": 1, "min": 0.7727567276784352, "max": 0.7727567276784352}}}
#
# #metrics {"StartTime": 1617645248.44259, "EndTime": 1617645248.4426072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.7228323327643531, "count": 1, "min": 0.7228323327643531, "max": 0.7228323327643531}}}
#
# #metrics {"StartTime": 1617645248.442662, "EndTime": 1617645248.4426787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.7497136316129139, "count": 1, "min": 0.7497136316129139, "max": 0.7497136316129139}}}
#
# #metrics {"StartTime": 1617645248.4427407, "EndTime": 1617645248.4427586, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.7744422448532922, "count": 1, "min": 0.7744422448532922, "max": 0.7744422448532922}}}
#
# #metrics {"StartTime": 1617645248.4428222, "EndTime": 1617645248.4428415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.761551314166614, "count": 1, "min": 0.761551314166614, "max": 0.761551314166614}}}
#
# #metrics {"StartTime": 1617645248.4428983, "EndTime": 1617645248.4429154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7674135672194617, "count": 1, "min": 0.7674135672194617, "max": 0.7674135672194617}}}
#
# #metrics {"StartTime": 1617645248.4429753, "EndTime": 1617645248.4429924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.9323073135954993, "count": 1, "min": 0.9323073135954993, "max": 0.9323073135954993}}}
#
# #metrics {"StartTime": 1617645248.4430466, "EndTime": 1617645248.4430633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7557860016822815, "count": 1, "min": 0.7557860016822815, "max": 0.7557860016822815}}}
#
# #metrics {"StartTime": 1617645248.4431179, "EndTime": 1617645248.443136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.7033289415495736, "count": 1, "min": 0.7033289415495736, "max": 0.7033289415495736}}}
#
# #metrics {"StartTime": 1617645248.4431994, "EndTime": 1617645248.4432194, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.7159294890505927, "count": 1, "min": 0.7159294890505927, "max": 0.7159294890505927}}}
#
# #metrics {"StartTime": 1617645248.443274, "EndTime": 1617645248.4432924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.7054997182318142, "count": 1, "min": 0.7054997182318142, "max": 0.7054997182318142}}}
#
# #metrics {"StartTime": 1617645248.443348, "EndTime": 1617645248.4433653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.7162931561470032, "count": 1, "min": 0.7162931561470032, "max": 0.7162931561470032}}}
#
# #metrics {"StartTime": 1617645248.4434218, "EndTime": 1617645248.4434397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9885507779461997, "count": 1, "min": 0.9885507779461997, "max": 0.9885507779461997}}}
#
# #metrics {"StartTime": 1617645248.4434938, "EndTime": 1617645248.4435112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9129248431750706, "count": 1, "min": 0.9129248431750706, "max": 0.9129248431750706}}}
#
# #metrics {"StartTime": 1617645248.4435666, "EndTime": 1617645248.443585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9887730096067701, "count": 1, "min": 0.9887730096067701, "max": 0.9887730096067701}}}
#
# #metrics {"StartTime": 1617645248.4436414, "EndTime": 1617645248.4436595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.940771085875375, "count": 1, "min": 0.940771085875375, "max": 0.940771085875375}}}
#
# #metrics {"StartTime": 1617645248.4437187, "EndTime": 1617645248.4437373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.2329992737088884, "count": 1, "min": 1.2329992737088884, "max": 1.2329992737088884}}}
#
# #metrics {"StartTime": 1617645248.4437845, "EndTime": 1617645248.4438012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.2317582326275962, "count": 1, "min": 1.2317582326275962, "max": 1.2317582326275962}}}
#
# #metrics {"StartTime": 1617645248.4438622, "EndTime": 1617645248.4438796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.2652883997985296, "count": 1, "min": 1.2652883997985296, "max": 1.2652883997985296}}}
#
# #metrics {"StartTime": 1617645248.443925, "EndTime": 1617645248.4439423, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.2143750190734863, "count": 1, "min": 1.2143750190734863, "max": 1.2143750190734863}}}
#
# [04/05/2021 17:54:08 INFO 139804451579712] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.7784910500049591
# #metrics {"StartTime": 1617645248.5279784, "EndTime": 1617645248.5280604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 34.785746256510414, "count": 1, "min": 34.785746256510414, "max": 34.785746256510414}}}
#
# #metrics {"StartTime": 1617645248.5281591, "EndTime": 1617645248.5281763, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 37.30368460860907, "count": 1, "min": 37.30368460860907, "max": 37.30368460860907}}}
#
# #metrics {"StartTime": 1617645248.5282242, "EndTime": 1617645248.528241, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 34.52365531173407, "count": 1, "min": 34.52365531173407, "max": 34.52365531173407}}}
#
# #metrics {"StartTime": 1617645248.5283048, "EndTime": 1617645248.5283225, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 31.460779526654413, "count": 1, "min": 31.460779526654413, "max": 31.460779526654413}}}
#
# #metrics {"StartTime": 1617645248.5283804, "EndTime": 1617645248.5283976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 38.87994743795956, "count": 1, "min": 38.87994743795956, "max": 38.87994743795956}}}
#
# #metrics {"StartTime": 1617645248.5284662, "EndTime": 1617645248.5284863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 42.45822562423407, "count": 1, "min": 42.45822562423407, "max": 42.45822562423407}}}
#
# #metrics {"StartTime": 1617645248.528547, "EndTime": 1617645248.5285642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 41.06542669558058, "count": 1, "min": 41.06542669558058, "max": 41.06542669558058}}}
#
# #metrics {"StartTime": 1617645248.5286229, "EndTime": 1617645248.5286412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 38.2546111462163, "count": 1, "min": 38.2546111462163, "max": 38.2546111462163}}}
#
# #metrics {"StartTime": 1617645248.5286913, "EndTime": 1617645248.5287023, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 40.60670261757046, "count": 1, "min": 40.60670261757046, "max": 40.60670261757046}}}
#
# #metrics {"StartTime": 1617645248.5287528, "EndTime": 1617645248.5287693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 33.8232697131587, "count": 1, "min": 33.8232697131587, "max": 33.8232697131587}}}
#
# #metrics {"StartTime": 1617645248.5288284, "EndTime": 1617645248.5288458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 33.959604300704655, "count": 1, "min": 33.959604300704655, "max": 33.959604300704655}}}
#
# #metrics {"StartTime": 1617645248.5289044, "EndTime": 1617645248.5289218, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 32.536064596737134, "count": 1, "min": 32.536064596737134, "max": 32.536064596737134}}}
#
# #metrics {"StartTime": 1617645248.5289812, "EndTime": 1617645248.529, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 38.1250353046492, "count": 1, "min": 38.1250353046492, "max": 38.1250353046492}}}
#
# #metrics {"StartTime": 1617645248.529066, "EndTime": 1617645248.5290844, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 37.10125852098652, "count": 1, "min": 37.10125852098652, "max": 37.10125852098652}}}
#
# #metrics {"StartTime": 1617645248.5291688, "EndTime": 1617645248.5291889, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 34.96441650390625, "count": 1, "min": 34.96441650390625, "max": 34.96441650390625}}}
#
# #metrics {"StartTime": 1617645248.529249, "EndTime": 1617645248.5292683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 35.86289948108149, "count": 1, "min": 35.86289948108149, "max": 35.86289948108149}}}
#
# #metrics {"StartTime": 1617645248.5293314, "EndTime": 1617645248.5293505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 30.33568498200061, "count": 1, "min": 30.33568498200061, "max": 30.33568498200061}}}
#
# #metrics {"StartTime": 1617645248.5294106, "EndTime": 1617645248.529429, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 35.756079580269606, "count": 1, "min": 35.756079580269606, "max": 35.756079580269606}}}
#
# #metrics {"StartTime": 1617645248.529479, "EndTime": 1617645248.5294967, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 36.64960075827206, "count": 1, "min": 36.64960075827206, "max": 36.64960075827206}}}
#
# #metrics {"StartTime": 1617645248.5295544, "EndTime": 1617645248.529573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 34.252310958563115, "count": 1, "min": 34.252310958563115, "max": 34.252310958563115}}}
#
# #metrics {"StartTime": 1617645248.5296292, "EndTime": 1617645248.529648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 31.251872941559437, "count": 1, "min": 31.251872941559437, "max": 31.251872941559437}}}
#
# #metrics {"StartTime": 1617645248.529704, "EndTime": 1617645248.5297205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 31.582146139705884, "count": 1, "min": 31.582146139705884, "max": 31.582146139705884}}}
#
# #metrics {"StartTime": 1617645248.529777, "EndTime": 1617645248.5297952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 32.781806497012866, "count": 1, "min": 32.781806497012866, "max": 32.781806497012866}}}
#
# #metrics {"StartTime": 1617645248.5298488, "EndTime": 1617645248.5298665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 31.615466547947303, "count": 1, "min": 31.615466547947303, "max": 31.615466547947303}}}
#
# #metrics {"StartTime": 1617645248.5299325, "EndTime": 1617645248.5299516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 65.50472005208333, "count": 1, "min": 65.50472005208333, "max": 65.50472005208333}}}
#
# #metrics {"StartTime": 1617645248.5300074, "EndTime": 1617645248.5300255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 65.71722292432598, "count": 1, "min": 65.71722292432598, "max": 65.71722292432598}}}
#
# #metrics {"StartTime": 1617645248.5300817, "EndTime": 1617645248.5301, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 61.884988223805145, "count": 1, "min": 61.884988223805145, "max": 61.884988223805145}}}
#
# #metrics {"StartTime": 1617645248.5301597, "EndTime": 1617645248.5301769, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 68.20221066942402, "count": 1, "min": 68.20221066942402, "max": 68.20221066942402}}}
#
# #metrics {"StartTime": 1617645248.53023, "EndTime": 1617645248.5302467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 63.25191722196691, "count": 1, "min": 63.25191722196691, "max": 63.25191722196691}}}
#
# #metrics {"StartTime": 1617645248.5303025, "EndTime": 1617645248.5303195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 62.56150668275122, "count": 1, "min": 62.56150668275122, "max": 62.56150668275122}}}
#
# #metrics {"StartTime": 1617645248.5303774, "EndTime": 1617645248.5303943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 53.509807511871934, "count": 1, "min": 53.509807511871934, "max": 53.509807511871934}}}
#
# #metrics {"StartTime": 1617645248.5304604, "EndTime": 1617645248.5304792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 70.90834434359681, "count": 1, "min": 70.90834434359681, "max": 70.90834434359681}}}
#
# [04/05/2021 17:54:08 INFO 139804451579712] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=34.785746256510414
# [04/05/2021 17:54:08 INFO 139804451579712] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=30.33568498200061
# [04/05/2021 17:54:08 INFO 139804451579712] Epoch 0: Loss improved. Updating best model
# [04/05/2021 17:54:08 INFO 139804451579712] Saving model for epoch: 0
# [04/05/2021 17:54:08 INFO 139804451579712] Saved checkpoint to "/tmp/tmp1_c58rti/mx-mod-0000.params"
# [04/05/2021 17:54:08 INFO 139804451579712] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1617645247.9799023, "EndTime": 1617645248.5439909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 942.0, "count": 1, "min": 942, "max": 942}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [04/05/2021 17:54:08 INFO 139804451579712] #throughput_metric: host=algo-1, train throughput=806.3798208174723 records/second
# #metrics {"StartTime": 1617645249.0003676, "EndTime": 1617645249.0004692, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.5072170804653849, "count": 1, "min": 0.5072170804653849, "max": 0.5072170804653849}}}
#
# #metrics {"StartTime": 1617645249.0005913, "EndTime": 1617645249.000618, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.546361834875175, "count": 1, "min": 0.546361834875175, "max": 0.546361834875175}}}
#
# #metrics {"StartTime": 1617645249.0006983, "EndTime": 1617645249.000719, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.534616734300341, "count": 1, "min": 0.534616734300341, "max": 0.534616734300341}}}
#
# #metrics {"StartTime": 1617645249.0007846, "EndTime": 1617645249.0008004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.47163782588073183, "count": 1, "min": 0.47163782588073183, "max": 0.47163782588073183}}}
#
# #metrics {"StartTime": 1617645249.0008533, "EndTime": 1617645249.0008688, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.35212001523801256, "count": 1, "min": 0.35212001523801256, "max": 0.35212001523801256}}}
#
# #metrics {"StartTime": 1617645249.0009243, "EndTime": 1617645249.0009427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.35506592265197207, "count": 1, "min": 0.35506592265197207, "max": 0.35506592265197207}}}
#
# #metrics {"StartTime": 1617645249.0009952, "EndTime": 1617645249.0010097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.3616079017519951, "count": 1, "min": 0.3616079017519951, "max": 0.3616079017519951}}}
#
# #metrics {"StartTime": 1617645249.0010657, "EndTime": 1617645249.0010822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.346369957285268, "count": 1, "min": 0.346369957285268, "max": 0.346369957285268}}}
#
# #metrics {"StartTime": 1617645249.0011642, "EndTime": 1617645249.0011804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.607893317937851, "count": 1, "min": 0.607893317937851, "max": 0.607893317937851}}}
#
# #metrics {"StartTime": 1617645249.0012283, "EndTime": 1617645249.0012426, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.5334499308041164, "count": 1, "min": 0.5334499308041164, "max": 0.5334499308041164}}}
#
# #metrics {"StartTime": 1617645249.0012925, "EndTime": 1617645249.0013092, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.5102784335613251, "count": 1, "min": 0.5102784335613251, "max": 0.5102784335613251}}}
#
# #metrics {"StartTime": 1617645249.0013642, "EndTime": 1617645249.001383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.5557666538017136, "count": 1, "min": 0.5557666538017136, "max": 0.5557666538017136}}}
#
# #metrics {"StartTime": 1617645249.0014372, "EndTime": 1617645249.0014546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.34562233090400696, "count": 1, "min": 0.34562233090400696, "max": 0.34562233090400696}}}
#
# #metrics {"StartTime": 1617645249.0015066, "EndTime": 1617645249.0015233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.34481352354799, "count": 1, "min": 0.34481352354799, "max": 0.34481352354799}}}
#
# #metrics {"StartTime": 1617645249.00158, "EndTime": 1617645249.001597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.34848009794950485, "count": 1, "min": 0.34848009794950485, "max": 0.34848009794950485}}}
#
# #metrics {"StartTime": 1617645249.0016494, "EndTime": 1617645249.0016656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.339957703437124, "count": 1, "min": 0.339957703437124, "max": 0.339957703437124}}}
#
# #metrics {"StartTime": 1617645249.0017135, "EndTime": 1617645249.0017276, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.5221486953752381, "count": 1, "min": 0.5221486953752381, "max": 0.5221486953752381}}}
#
# #metrics {"StartTime": 1617645249.001774, "EndTime": 1617645249.0017884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.547375391636576, "count": 1, "min": 0.547375391636576, "max": 0.547375391636576}}}
#
# #metrics {"StartTime": 1617645249.0018423, "EndTime": 1617645249.0018604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.5701102625046458, "count": 1, "min": 0.5701102625046458, "max": 0.5701102625046458}}}
#
# #metrics {"StartTime": 1617645249.0019174, "EndTime": 1617645249.0019364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.5569039391619819, "count": 1, "min": 0.5569039391619819, "max": 0.5569039391619819}}}
#
# #metrics {"StartTime": 1617645249.0020077, "EndTime": 1617645249.0020251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.48210738812174114, "count": 1, "min": 0.48210738812174114, "max": 0.48210738812174114}}}
#
# #metrics {"StartTime": 1617645249.0020924, "EndTime": 1617645249.0021112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.47698893610920223, "count": 1, "min": 0.47698893610920223, "max": 0.47698893610920223}}}
#
# #metrics {"StartTime": 1617645249.002183, "EndTime": 1617645249.0022016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.48275414428540636, "count": 1, "min": 0.48275414428540636, "max": 0.48275414428540636}}}
#
# #metrics {"StartTime": 1617645249.0022655, "EndTime": 1617645249.002282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.4838105333702905, "count": 1, "min": 0.4838105333702905, "max": 0.4838105333702905}}}
#
# #metrics {"StartTime": 1617645249.0023324, "EndTime": 1617645249.0023465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9566387065819332, "count": 1, "min": 0.9566387065819332, "max": 0.9566387065819332}}}
#
# #metrics {"StartTime": 1617645249.0024047, "EndTime": 1617645249.0024216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9717990287712642, "count": 1, "min": 0.9717990287712642, "max": 0.9717990287712642}}}
#
# #metrics {"StartTime": 1617645249.0024788, "EndTime": 1617645249.0024962, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9333398938179016, "count": 1, "min": 0.9333398938179016, "max": 0.9333398938179016}}}
#
# #metrics {"StartTime": 1617645249.0025563, "EndTime": 1617645249.0025752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9579582810401917, "count": 1, "min": 0.9579582810401917, "max": 0.9579582810401917}}}
#
# #metrics {"StartTime": 1617645249.002634, "EndTime": 1617645249.002652, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0117083958217077, "count": 1, "min": 1.0117083958217077, "max": 1.0117083958217077}}}
#
# #metrics {"StartTime": 1617645249.0027103, "EndTime": 1617645249.0027282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.013779137815748, "count": 1, "min": 1.013779137815748, "max": 1.013779137815748}}}
#
# #metrics {"StartTime": 1617645249.0027838, "EndTime": 1617645249.0027995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.0020378934485572, "count": 1, "min": 1.0020378934485572, "max": 1.0020378934485572}}}
#
# #metrics {"StartTime": 1617645249.0028524, "EndTime": 1617645249.0028677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0241867154836655, "count": 1, "min": 1.0241867154836655, "max": 1.0241867154836655}}}
#
# [04/05/2021 17:54:09 INFO 139804451579712] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.5072170804653849
# #metrics {"StartTime": 1617645249.0980272, "EndTime": 1617645249.098112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 31.11800429400276, "count": 1, "min": 31.11800429400276, "max": 31.11800429400276}}}
#
# #metrics {"StartTime": 1617645249.0982149, "EndTime": 1617645249.0982385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 32.392526663985905, "count": 1, "min": 32.392526663985905, "max": 32.392526663985905}}}
#
# #metrics {"StartTime": 1617645249.0983102, "EndTime": 1617645249.09833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 28.869810216567096, "count": 1, "min": 28.869810216567096, "max": 28.869810216567096}}}
#
# #metrics {"StartTime": 1617645249.0983808, "EndTime": 1617645249.0983994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 27.498380174823836, "count": 1, "min": 27.498380174823836, "max": 27.498380174823836}}}
#
# #metrics {"StartTime": 1617645249.0984478, "EndTime": 1617645249.0984657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 34.4507625804228, "count": 1, "min": 34.4507625804228, "max": 34.4507625804228}}}
#
# #metrics {"StartTime": 1617645249.0985239, "EndTime": 1617645249.0985415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 38.147970760569855, "count": 1, "min": 38.147970760569855, "max": 38.147970760569855}}}
#
# #metrics {"StartTime": 1617645249.0985885, "EndTime": 1617645249.0986059, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 34.71146168428309, "count": 1, "min": 34.71146168428309, "max": 34.71146168428309}}}
#
# #metrics {"StartTime": 1617645249.0986502, "EndTime": 1617645249.0986674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 34.916889265471816, "count": 1, "min": 34.916889265471816, "max": 34.916889265471816}}}
#
# #metrics {"StartTime": 1617645249.0987234, "EndTime": 1617645249.098741, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 32.748390347349876, "count": 1, "min": 32.748390347349876, "max": 32.748390347349876}}}
#
# #metrics {"StartTime": 1617645249.0987873, "EndTime": 1617645249.0988047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 28.75741397633272, "count": 1, "min": 28.75741397633272, "max": 28.75741397633272}}}
#
# #metrics {"StartTime": 1617645249.0988529, "EndTime": 1617645249.0988705, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 30.211978089575673, "count": 1, "min": 30.211978089575673, "max": 30.211978089575673}}}
#
# #metrics {"StartTime": 1617645249.0989258, "EndTime": 1617645249.0989437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 27.256429036458332, "count": 1, "min": 27.256429036458332, "max": 27.256429036458332}}}
#
# #metrics {"StartTime": 1617645249.0989907, "EndTime": 1617645249.0990083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 36.565314797794116, "count": 1, "min": 36.565314797794116, "max": 36.565314797794116}}}
#
# #metrics {"StartTime": 1617645249.0990562, "EndTime": 1617645249.0990741, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 36.69375430836397, "count": 1, "min": 36.69375430836397, "max": 36.69375430836397}}}
#
# #metrics {"StartTime": 1617645249.0991337, "EndTime": 1617645249.0991518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 37.44238879633885, "count": 1, "min": 37.44238879633885, "max": 37.44238879633885}}}
#
# #metrics {"StartTime": 1617645249.0991993, "EndTime": 1617645249.0992153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 35.61846564797794, "count": 1, "min": 35.61846564797794, "max": 35.61846564797794}}}
#
# #metrics {"StartTime": 1617645249.0992665, "EndTime": 1617645249.0992837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 25.43794998468137, "count": 1, "min": 25.43794998468137, "max": 25.43794998468137}}}
#
# #metrics {"StartTime": 1617645249.0993378, "EndTime": 1617645249.0993543, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 29.427255069508274, "count": 1, "min": 29.427255069508274, "max": 29.427255069508274}}}
#
# #metrics {"StartTime": 1617645249.099409, "EndTime": 1617645249.0994267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 27.035483565984986, "count": 1, "min": 27.035483565984986, "max": 27.035483565984986}}}
#
# #metrics {"StartTime": 1617645249.0994823, "EndTime": 1617645249.0994995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 28.107681573606005, "count": 1, "min": 28.107681573606005, "max": 28.107681573606005}}}
#
# #metrics {"StartTime": 1617645249.0995574, "EndTime": 1617645249.099575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 29.757208132276347, "count": 1, "min": 29.757208132276347, "max": 29.757208132276347}}}
#
# #metrics {"StartTime": 1617645249.0996306, "EndTime": 1617645249.0996482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 30.308175479664524, "count": 1, "min": 30.308175479664524, "max": 30.308175479664524}}}
#
# #metrics {"StartTime": 1617645249.0997105, "EndTime": 1617645249.0997293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 28.713680491727942, "count": 1, "min": 28.713680491727942, "max": 28.713680491727942}}}
#
# #metrics {"StartTime": 1617645249.099788, "EndTime": 1617645249.0998075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 29.026183483647365, "count": 1, "min": 29.026183483647365, "max": 29.026183483647365}}}
#
# #metrics {"StartTime": 1617645249.0998564, "EndTime": 1617645249.0998743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 65.43939568014706, "count": 1, "min": 65.43939568014706, "max": 65.43939568014706}}}
#
# #metrics {"StartTime": 1617645249.09992, "EndTime": 1617645249.0999374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 66.29186054304535, "count": 1, "min": 66.29186054304535, "max": 66.29186054304535}}}
#
# #metrics {"StartTime": 1617645249.0999937, "EndTime": 1617645249.100012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 66.83481014476104, "count": 1, "min": 66.83481014476104, "max": 66.83481014476104}}}
#
# #metrics {"StartTime": 1617645249.1000564, "EndTime": 1617645249.100073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 66.3905029296875, "count": 1, "min": 66.3905029296875, "max": 66.3905029296875}}}
#
# #metrics {"StartTime": 1617645249.100125, "EndTime": 1617645249.1001403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 74.03523284313725, "count": 1, "min": 74.03523284313725, "max": 74.03523284313725}}}
#
# #metrics {"StartTime": 1617645249.1001875, "EndTime": 1617645249.100203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 69.40413650811887, "count": 1, "min": 69.40413650811887, "max": 69.40413650811887}}}
#
# ...
#
# #metrics {"StartTime": 1617645253.9843056, "EndTime": 1617645253.984323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9595901327473777, "count": 1, "min": 0.9595901327473777, "max": 0.9595901327473777}}}
#
# #metrics {"StartTime": 1617645253.9843667, "EndTime": 1617645253.9843829, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9592129673276629, "count": 1, "min": 0.9592129673276629, "max": 0.9592129673276629}}}
#
# #metrics {"StartTime": 1617645253.9844265, "EndTime": 1617645253.9844425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9600411483219692, "count": 1, "min": 0.9600411483219692, "max": 0.9600411483219692}}}
#
# #metrics {"StartTime": 1617645253.9845006, "EndTime": 1617645253.984518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9610849831785474, "count": 1, "min": 0.9610849831785474, "max": 0.9610849831785474}}}
#
# [04/05/2021 17:54:13 INFO 139804451579712] #quality_metric: host=algo-1, epoch=10, train mse_objective <loss>=0.25864617845841814
# #metrics {"StartTime": 1617645254.0595932, "EndTime": 1617645254.0596554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 23.305978812423408, "count": 1, "min": 23.305978812423408, "max": 23.305978812423408}}}
#
# #metrics {"StartTime": 1617645254.05974, "EndTime": 1617645254.0597584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 23.4967788995481, "count": 1, "min": 23.4967788995481, "max": 23.4967788995481}}}
#
# #metrics {"StartTime": 1617645254.0598185, "EndTime": 1617645254.0598357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 23.47379976160386, "count": 1, "min": 23.47379976160386, "max": 23.47379976160386}}}
#
# #metrics {"StartTime": 1617645254.0598938, "EndTime": 1617645254.0599113, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 23.404445872587317, "count": 1, "min": 23.404445872587317, "max": 23.404445872587317}}}
#
# #metrics {"StartTime": 1617645254.0599647, "EndTime": 1617645254.0599809, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 26.076457304113053, "count": 1, "min": 26.076457304113053, "max": 26.076457304113053}}}
#
# #metrics {"StartTime": 1617645254.0600305, "EndTime": 1617645254.0600467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 26.871011771407783, "count": 1, "min": 26.871011771407783, "max": 26.871011771407783}}}
#
# #metrics {"StartTime": 1617645254.0601017, "EndTime": 1617645254.0601182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 26.18737134746477, "count": 1, "min": 26.18737134746477, "max": 26.18737134746477}}}
#
# #metrics {"StartTime": 1617645254.0601716, "EndTime": 1617645254.060188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 26.715603099149817, "count": 1, "min": 26.715603099149817, "max": 26.715603099149817}}}
#
# #metrics {"StartTime": 1617645254.0602422, "EndTime": 1617645254.0602593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 22.942757999195774, "count": 1, "min": 22.942757999195774, "max": 22.942757999195774}}}
#
# #metrics {"StartTime": 1617645254.060313, "EndTime": 1617645254.0603302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 23.12463259229473, "count": 1, "min": 23.12463259229473, "max": 23.12463259229473}}}
#
# #metrics {"StartTime": 1617645254.0603826, "EndTime": 1617645254.0603993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 22.95575070848652, "count": 1, "min": 22.95575070848652, "max": 22.95575070848652}}}
#
# #metrics {"StartTime": 1617645254.060455, "EndTime": 1617645254.060472, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 23.114502551508885, "count": 1, "min": 23.114502551508885, "max": 23.114502551508885}}}
#
# #metrics {"StartTime": 1617645254.060527, "EndTime": 1617645254.060544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 25.678783940333947, "count": 1, "min": 25.678783940333947, "max": 25.678783940333947}}}
#
# #metrics {"StartTime": 1617645254.060601, "EndTime": 1617645254.060619, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 26.660432104970894, "count": 1, "min": 26.660432104970894, "max": 26.660432104970894}}}
#
# #metrics {"StartTime": 1617645254.0606713, "EndTime": 1617645254.0606866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 25.781185374540442, "count": 1, "min": 25.781185374540442, "max": 25.781185374540442}}}
#
# #metrics {"StartTime": 1617645254.0607517, "EndTime": 1617645254.06077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 26.338398054534313, "count": 1, "min": 26.338398054534313, "max": 26.338398054534313}}}
#
# #metrics {"StartTime": 1617645254.0608277, "EndTime": 1617645254.0608435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 21.160675048828125, "count": 1, "min": 21.160675048828125, "max": 21.160675048828125}}}
#
# #metrics {"StartTime": 1617645254.0608885, "EndTime": 1617645254.0609047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 21.346051384420957, "count": 1, "min": 21.346051384420957, "max": 21.346051384420957}}}
#
# #metrics {"StartTime": 1617645254.060969, "EndTime": 1617645254.0609865, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 21.138158461626837, "count": 1, "min": 21.138158461626837, "max": 21.138158461626837}}}
#
# #metrics {"StartTime": 1617645254.0610254, "EndTime": 1617645254.061035, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 21.2135404698989, "count": 1, "min": 21.2135404698989, "max": 21.2135404698989}}}
#
# #metrics {"StartTime": 1617645254.0610888, "EndTime": 1617645254.0611339, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 23.945702646292894, "count": 1, "min": 23.945702646292894, "max": 23.945702646292894}}}
#
# #metrics {"StartTime": 1617645254.0611928, "EndTime": 1617645254.061211, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 25.159806793811274, "count": 1, "min": 25.159806793811274, "max": 25.159806793811274}}}
#
# #metrics {"StartTime": 1617645254.0612657, "EndTime": 1617645254.0612793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 23.964001225490197, "count": 1, "min": 23.964001225490197, "max": 23.964001225490197}}}
#
# #metrics {"StartTime": 1617645254.061332, "EndTime": 1617645254.0613453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 25.185130399816178, "count": 1, "min": 25.185130399816178, "max": 25.185130399816178}}}
#
# #metrics {"StartTime": 1617645254.0614033, "EndTime": 1617645254.0614204, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 65.43176748238358, "count": 1, "min": 65.43176748238358, "max": 65.43176748238358}}}
#
# #metrics {"StartTime": 1617645254.0614765, "EndTime": 1617645254.0614939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 65.42610198376225, "count": 1, "min": 65.42610198376225, "max": 65.42610198376225}}}
#
# #metrics {"StartTime": 1617645254.0615573, "EndTime": 1617645254.0615745, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 65.4402214499081, "count": 1, "min": 65.4402214499081, "max": 65.4402214499081}}}
#
# #metrics {"StartTime": 1617645254.0616295, "EndTime": 1617645254.061646, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 65.53111356847427, "count": 1, "min": 65.53111356847427, "max": 65.53111356847427}}}
#
# #metrics {"StartTime": 1617645254.061697, "EndTime": 1617645254.0617132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 64.37389658011642, "count": 1, "min": 64.37389658011642, "max": 64.37389658011642}}}
#
# #metrics {"StartTime": 1617645254.061766, "EndTime": 1617645254.061783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 64.7226682176777, "count": 1, "min": 64.7226682176777, "max": 64.7226682176777}}}
#
# #metrics {"StartTime": 1617645254.0618353, "EndTime": 1617645254.0618532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 64.5021302466299, "count": 1, "min": 64.5021302466299, "max": 64.5021302466299}}}
#
# #metrics {"StartTime": 1617645254.0619178, "EndTime": 1617645254.0619366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 66.66134583716298, "count": 1, "min": 66.66134583716298, "max": 66.66134583716298}}}
#
# [04/05/2021 17:54:14 INFO 139804451579712] #quality_metric: host=algo-1, epoch=10, validation mse_objective <loss>=23.305978812423408
# [04/05/2021 17:54:14 INFO 139804451579712] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=mse_objective, value=21.138158461626837
# [04/05/2021 17:54:14 INFO 139804451579712] Saving model for epoch: 10
# [04/05/2021 17:54:14 INFO 139804451579712] Saved checkpoint to "/tmp/tmpgccc4sn6/mx-mod-0000.params"
# [04/05/2021 17:54:14 INFO 139804451579712] Early stop condition met. Stopping training.
# [04/05/2021 17:54:14 INFO 139804451579712] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1617645253.5188544, "EndTime": 1617645254.0689359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5492.0, "count": 1, "min": 5492, "max": 5492}, "Total Batches Seen": {"sum": 181.0, "count": 1, "min": 181, "max": 181}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [04/05/2021 17:54:14 INFO 139804451579712] #throughput_metric: host=algo-1, train throughput=826.9089667495998 records/second
# [04/05/2021 17:54:14 WARNING 139804451579712] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/05/2021 17:54:14 WARNING 139804451579712] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/05/2021 17:54:14 INFO 139804451579712] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=mse_objective, value=21.138158461626837
# [04/05/2021 17:54:14 INFO 139804451579712] #validation_score (algo-1) : ('mse_objective', 21.017040776271447)
# [04/05/2021 17:54:14 INFO 139804451579712] #validation_score (algo-1) : ('mse', 21.017040776271447)
# [04/05/2021 17:54:14 INFO 139804451579712] #validation_score (algo-1) : ('absolute_loss', 3.47117644665288)
# [04/05/2021 17:54:14 INFO 139804451579712] #quality_metric: host=algo-1, validation mse_objective <loss>=21.017040776271447
# [04/05/2021 17:54:14 INFO 139804451579712] #quality_metric: host=algo-1, validation mse <loss>=21.017040776271447
# [04/05/2021 17:54:14 INFO 139804451579712] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.47117644665288
# [04/05/2021 17:54:14 INFO 139804451579712] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 1, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [04/05/2021 17:54:14 INFO 139804451579712] Saved checkpoint to "/tmp/tmpablaujto/mx-mod-0000.params"
# [04/05/2021 17:54:14 INFO 139804451579712] Test data is not provided.
# #metrics {"StartTime": 1617645247.6072054, "EndTime": 1617645254.1645432, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 357.03349113464355, "count": 1, "min": 357.03349113464355, "max": 357.03349113464355}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 10.841131210327148, "count": 12, "min": 0.24819374084472656, "max": 1.5933513641357422}, "update.time": {"sum": 6042.161464691162, "count": 11, "min": 446.5441703796387, "max": 644.1116333007812}, "finalize.time": {"sum": 89.3394947052002, "count": 1, "min": 89.3394947052002, "max": 89.3394947052002}, "setuptime": {"sum": 26.331663131713867, "count": 1, "min": 26.331663131713867, "max": 26.331663131713867}, "totaltime": {"sum": 6813.115835189819, "count": 1, "min": 6813.115835189819, "max": 6813.115835189819}}}
#
#
# 2021-04-05 17:54:31 Completed - Training job completed
# Training seconds: 75
# Billable seconds: 75

# %%
# %%bash -s "$ll_estimator.output_path"
# aws s3 ls --recursive $1
# Out:
# 2021-04-05 07:51:40        938 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/output/model.tar.gz
# 2021-04-05 07:51:50          0 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/profiler-output/framework/training_job_end.ts
# 2021-04-05 07:51:38     135448 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/profiler-output/system/incremental/2021040507/1617609000.algo-1.json
# 2021-04-05 07:51:38     147490 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/profiler-output/system/incremental/2021040507/1617609060.algo-1.json
# 2021-04-05 07:51:50          0 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/profiler-output/system/training_job_end.ts
# 2021-04-05 07:51:57     322341 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-report.html
# 2021-04-05 07:51:56     168685 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-report.ipynb
# 2021-04-05 07:51:53        190 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/BatchSize.json
# 2021-04-05 07:51:53        198 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/CPUBottleneck.json
# 2021-04-05 07:51:53        126 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/Dataloader.json
# 2021-04-05 07:51:53        127 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/GPUMemoryIncrease.json
# 2021-04-05 07:51:53        197 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/IOBottleneck.json
# 2021-04-05 07:51:53        119 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/LoadBalancing.json
# 2021-04-05 07:51:53        151 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/LowGPUUtilization.json
# 2021-04-05 07:51:53        179 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/MaxInitializationTime.json
# 2021-04-05 07:51:53        133 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# 2021-04-05 07:51:53        464 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/OverallSystemUsage.json
# 2021-04-05 07:51:53        156 boston-housing/output/linear-learner-2021-04-05-07-47-34-919/rule-output/ProfilerReport-1617608854/profiler-output/profiler-reports/StepOutlier.json
# 2021-04-05 17:54:20        933 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/output/model.tar.gz
# 2021-04-05 17:54:23          0 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/profiler-output/framework/training_job_end.ts
# 2021-04-05 17:54:18     195423 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/profiler-output/system/incremental/2021040517/1617645180.algo-1.json
# 2021-04-05 17:54:18      68693 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/profiler-output/system/incremental/2021040517/1617645240.algo-1.json
# 2021-04-05 17:54:23          0 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/profiler-output/system/training_job_end.ts
# 2021-04-05 17:55:02     322342 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-report.html
# 2021-04-05 17:55:02     168687 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-report.ipynb
# 2021-04-05 17:54:58        190 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/BatchSize.json
# 2021-04-05 17:54:58        199 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/CPUBottleneck.json
# 2021-04-05 17:54:58        126 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/Dataloader.json
# 2021-04-05 17:54:58        127 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/GPUMemoryIncrease.json
# 2021-04-05 17:54:58        198 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/IOBottleneck.json
# 2021-04-05 17:54:58        119 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/LoadBalancing.json
# 2021-04-05 17:54:58        151 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/LowGPUUtilization.json
# 2021-04-05 17:54:58        179 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/MaxInitializationTime.json
# 2021-04-05 17:54:58        133 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# 2021-04-05 17:54:58        464 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/OverallSystemUsage.json
# 2021-04-05 17:54:58        156 boston-housing/output/linear-learner-2021-04-05-17-50-47-135/rule-output/ProfilerReport-1617645047/profiler-output/profiler-reports/StepOutlier.json

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())
endpoint_name = 'linear-learner-demo-'+timestamp

#print endpoint name
print(endpoint_name)
# Out:
# linear-learner-demo-05-17-55-49

# %%
ll_predictor = ll_estimator.deploy(
 endpoint_name=endpoint_name,
 initial_instance_count=1,
 instance_type='ml.t2.medium')
# Out:
# -----------------!

# %%
ll_predictor.content_type = 'text'
ll_predictor.serializer = sagemaker.serializers.CSVSerializer()
ll_predictor.deserializer = sagemaker.deserializers.CSVDeserializer()

# %%
test_sample = '0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,4.98'

# %%
response = ll_predictor.predict(test_sample)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# <ipython-input-44-9cb76fa3f0eb> in <module>
# ----> 1 response = ll_predictor.predict(test_sample)
#       2 print(response)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in predict(self, data, initial_args, target_model, target_variant, inference_id)
#     134             data, initial_args, target_model, target_variant, inference_id
#     135         )
# --> 136         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#     137         return self._handle_response(response)
#     138
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ModelError: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from model with message "unable to evaluate payload provided". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/linear-learner-demo-05-17-55-49 in account 373913539787 for more information.
